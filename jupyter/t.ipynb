# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# # Esecuzione KS

# %%
types = ['uncorr', 'inv', 'str', 'almost', 'weak']
types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']

df = pd.read_csv('csv/columns_t/csv_c50000_n100_r50000_fn100_mode5_div1_cut1.csv', sep=',', decimal='.')
#df['time_ks2_v1_allocation'] = df['time_ks2_v1_allocation'].astype(float)





# for nr, i in enumerate(types):
#     val = df[df['typename'] == i]
#     plt.hist(val['time_original'])
#     #val['time_original'].plot.hist()
#     plt.title(types_conv[nr])
#     plt.show()



# for nr, i in enumerate(types):
#     df['time_ks2_v1_allocation'].plot.box()
# df['time_ks2_v1'].plot.box()
print("v1:")
for nr, i in enumerate(types):
    val = df[df['typename'] == i]
    val['time_ks2_v1'].plot.box()
    plt.title(types_conv[nr])
    plt.xlabel('Tempo[s]')
    plt.ylabel('Frequenza')
    #plt.xticks([1, 2], ['Tick Label 1', 'Tick Label 2'])
    plt.show()

print("v1 t:")
for nr, i in enumerate(types):
    val = df[df['typename'] == i]
    val['time_ks2_v1_1'].plot.box()
    plt.title(types_conv[nr])
    plt.xlabel('Tempo[s]')
    plt.ylabel('Frequenza')
    #plt.xticks([1, 2], ['Tick Label 1', 'Tick Label 2'])
    plt.show()

print("v2:")
for nr, i in enumerate(types):
    val = df[df['typename'] == i]
    val['time_ks2_v2'].plot.box()
    plt.title(types_conv[nr])
    plt.xlabel('Tempo[s]')
    plt.ylabel('Frequenza')
    #plt.xticks([1, 2], ['Tick Label 1', 'Tick Label 2'])
    plt.show()

print("v2 t:")
for nr, i in enumerate(types):
    val = df[df['typename'] == i]
    val['time_ks2_v2_1'].plot.box()
    plt.title(types_conv[nr])
    plt.xlabel('Tempo[s]')
    plt.ylabel('Frequenza')
    #plt.xticks([1, 2], ['Tick Label 1', 'Tick Label 2'])
    plt.show()
# Out:
# v1:
# v1 t:
# v2:
# v2 t:

# %%
types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']
import matplotlib.pyplot as plt

# Creazione della figura e degli assi
for nr, i in enumerate(types):
    fig, ax = plt.subplots()
    # Creazione dei boxplot
    val = df[df['typename'] == i]
    bp1 = ax.boxplot(val['time_ks2_v1'], positions=[nr*2-0.4], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C0'))
    bp2 = ax.boxplot(val['time_ks2_v1_1'], positions=[nr*2+0.4], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C1'))
    # Personalizzazione degli assi e della legenda
    ax.set_xticklabels(['', ''])
    ax.set_xlabel('Tipo')
    ax.set_ylabel('Tempo [s]')
    plt.title(f"{types_conv[nr]}")
    ax.legend([bp1["boxes"][0], bp2["boxes"][0]], ['ks2 + mincapv1', 'ks2 + mincapv1 + t\''], loc='upper right')
    # Visualizzazione del grafico
    plt.show()

# %%
types = ['uncorr', 'inv', 'str', 'almost', 'weak']
types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']

df = pd.read_csv('csv/columns_t/csv_c50000_n100_r50000_fn100_mode5_div1_cut1.csv', sep=',', decimal='.')
#df['time_ks2_v1_allocation'] = df['time_ks2_v1_allocation'].astype(float)

types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']
import matplotlib.pyplot as plt

# Creazione della figura e degli assi
for nr, i in enumerate(types):
    fig, ax = plt.subplots()
    # Creazione dei boxplot
    val = df[df['typename'] == i]
    bp1 = ax.boxplot(val['time_ks2_v2'], positions=[nr*2-0.4], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C0'))
    bp2 = ax.boxplot(val['time_ks2_v2_1'], positions=[nr*2+0.4], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C1'))
    # Personalizzazione degli assi e della legenda
    ax.set_xticklabels(['', ''])
    ax.set_xlabel('Tipo')
    ax.set_ylabel('Tempo [s]')
    plt.title(f"{types_conv[nr]}")
    ax.legend([bp1["boxes"][0], bp2["boxes"][0]], ['ks2 + mincapv2', 'ks2 + mincapv2 + t\''], loc='upper right')
    # Visualizzazione del grafico
    plt.show()

types = df['typename'].unique()

means = df.groupby('typename').mean()
variances = df.groupby('typename').var()

#means[['time_ks2_v1', 'time_ks2_v1_1', 'time_ks2_v2', 'time_ks2_v2_1']]
variances[['time_ks2_v1', 'time_ks2_v1_1', 'time_ks2_v2', 'time_ks2_v2_1']]
# Out:
#           time_ks2_v1  time_ks2_v1_1  time_ks2_v2  time_ks2_v2_1
# typename
# almost       0.000002       0.000002     0.000008       0.000006
# inv          0.000097       0.000003     0.000154       0.000009
# str          0.000010       0.000004     0.000016       0.000010
# uncorr       0.000036       0.000008     0.000032       0.000008
# weak         0.000010       0.000002     0.000018       0.000006

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 types = csv['typename'].unique()
#       3 means = csv.groupby('typename').mean()
#       4 variances = csv.groupby('typename').var()
#
# NameError: name 'csv' is not defined

# %% [markdown]
# # Times

# %%
types = ['uncorr', 'inv', 'str', 'almost', 'weak']
types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']

# df = pd.read_csv('csv/columns_t/csv_c50000_n10_r50000_fn100_mode5_div1_cut1.csv', sep=',', decimal='.')
df = pd.read_csv('csv/columns_t/csv_c50000_n100_r50000_fn100_mode5_div1_cut1.csv', sep=',', decimal='.')

types_conv = ['Non correlati', 'Correlazione inversa', 'Correlazione forte', 'Quasi correlati', 'Correlazione debole']
import matplotlib.pyplot as plt
#Creazione della figura e degli assi
for nr, i in enumerate(types):
    fig, ax = plt.subplots()
    # Creazione dei boxplot
    val = df[df['typename'] == i]
    bp1 = ax.boxplot(val['time_ks2_v1_1'], positions=[nr*2-0.4], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C0'))
    bp2 = ax.boxplot(val['time_ks2_v2_1'], positions=[nr*2+0.2], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C1'))
    bp3 = ax.boxplot(val['time_original'], positions=[nr*2+0.8], widths=0.4, patch_artist=True, boxprops=dict(facecolor='C3'))
    # Personalizzazione degli assi e della legenda
    ax.set_xticklabels(['', '', ''])
    ax.set_xlabel('Tipo')
    ax.set_ylabel('Tempo [s]')
    plt.title(f"{types_conv[nr]}")
    ax.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0]], ['minCapV1','minCapv2', 'Original'], loc='upper left')
    # Visualizzazione del grafico
    plt.show()

types = df['typename'].unique()

means = df.groupby('typename').mean()
variances = df.groupby('typename').var()

#means[['time_ks2_v1', 'time_ks2_v1_1', 'time_ks2_v2', 'time_ks2_v2_1', 'time_original']]


#variances[['time_ks2_v1', 'time_ks2_v1_1', 'time_ks2_v2', 'time_ks2_v2_1','time_original']]

sums = df.groupby('typename').sum()
sums[['time_ks2_v1', 'time_ks2_v1_1', 'time_ks2_v2', 'time_ks2_v2_1','time_original']]
# Out:
#           time_ks2_v1  time_ks2_v1_1  time_ks2_v2  time_ks2_v2_1  \
# typename
# almost       3.490676       2.921187     3.461569       2.946212
# inv         54.279136       2.675350    54.406656       2.693954
# str          4.703039       3.024942     4.648377       3.043193
# uncorr       7.283048       2.876356     7.221262       2.879754
# weak         6.101459       2.936083     6.146906       2.954586
#
#           time_original
# typename
# almost         3.771529
# inv            3.738523
# str            3.944173
# uncorr         3.719661
# weak           3.835763

# %% [markdown]
# ## means

# %%
means
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 means
#
# NameError: name 'means' is not defined

# %%
variances
# Out:
#           time_original  time_original_prealloc
# typename
# almost         0.000482                0.000221
# inv            0.000411                0.000233
# str            0.000511                0.000414
# uncorr         0.011199                0.000401
# weak           0.000935                0.000280

# %%
cols = ['time_original']
titles = ['Original']

means[cols].plot.box()
plt.gca().set_xticklabels(titles)
plt.gca().set_ylabel('tempo[s]')
plt.show()

for i, col in enumerate(cols):
    fig, ax = plt.subplots()
    means[col].plot.bar()
    ax.set_title(titles[i])
    ax.set_ylabel('Tempo[s]')
    ax.set_xlabel('tipo di relazione')
    plt.show()


print("preallocazione:")


cols = ['time_original', 'time_original_prealloc']
titles = ['Original', 'Original con preallocazione']

means[cols].plot.box()
plt.gca().set_xticklabels(titles)
plt.gca().set_ylabel('tempo[s]')
plt.show()

for i, col in enumerate(cols):
    fig, ax = plt.subplots()
    means[col].plot.bar()
    ax.set_title(titles[i])
    ax.set_ylabel('Tempo[s]')
    ax.set_xlabel('tipo di relazione')
    plt.show()

for i, col in enumerate(cols):
    means[col].plot.bar()
plt.show()



# Crea la figura e l'oggetto axes
fig, ax = plt.subplots()


# Plotta il primo grafico
# means[col].plot.bar(ax=ax, color='blue')

# means[col].plot.bar(ax=ax, color='green')

means['time_original'].plot.bar(ax=ax)

means['time_original_prealloc'].plot.bar(ax=ax, color='orange')

# Aggiungi la legenda
ax.legend(['Original', 'Prealloc'])

# Visualizza il grafico
plt.show()
# Out:
# preallocazione:
